# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Theory

# %% [markdown]
# # Pandas is an open-source software library for the Python programming language designed for data manipulation and analysis. It provides powerful and flexible data structures, particularly the DataFrame and Series.

# %% [markdown]
# # Data Manipulation and Analysis:
# ### Read & Write Data: Easily load data from various formats like CSV, Excel, SQL databases, and JSON.
# ### Data Clean : Handle Missing Data (e.g., Filling or Dropping Null Values), Remove Duplicates, and transform Correct Format.
# ### Data Selection and Filtering: Select specific columns, rows, or subsets of data based on conditions.
# ### Data Transformation: Reshape, Pivot, Merge, or Join DataFrames, as well as apply functions to transform data.
# ### Aggregation and Grouping: Applied Sums, Averages, or Counts on groups of data by the groupby() function.

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\retail sales.csv")
df[0:3]
# Out:
#          Date                Product Name Product Type       Brand  Gender  \
# 0  2022-05-27  Fear of God Essentials Tee      T-shirt  Essentials  Unisex
# 1  2022-08-22             Yeezy Boost 350     Sneakers      Adidas  Unisex
# 2  2022-04-03               Nike Dunk Low     Sneakers        Nike   Women
#
#           Category  Country  Quantity  Unit Price ($)  Amount ($)  \
# 0  Limited Edition    Japan         5          141.82      709.10
# 1       Streetwear      USA         2          267.34      534.68
# 2  Limited Edition  Germany         1          292.00      292.00
#
#        Payment Mode
# 0              Card
# 1  Cash on Delivery
# 2  Cash on Delivery

# %% [markdown]
# # 1.Pandas Series

# %% [markdown]
# # A one-dimensional array or Data holds any data type. It has a single column or row of a DataFrame.

# %%
labels=['Name','Age','Height','Weight','Address']
S=pd.Series(labels)
S
# Out:
# 0       Name
# 1        Age
# 2     Height
# 3     Weight
# 4    Address
# dtype: object

# %%
my_series_2=['Aaron',29,180,75,'Austin,Texas']
Ser=pd.Series(my_series_2,labels)
Ser
# Out:
# Name              Aaron
# Age                  29
# Height              180
# Weight               75
# Address    Austin,Texas
# dtype: object

# %%
my_Ser=pd.Series(my_series_2,index=labels)
my_Ser
# Out:
# Name              Aaron
# Age                  29
# Height              180
# Weight               75
# Address    Austin,Texas
# dtype: object

# %%
Ser_1=pd.Series([10,20,30,400,500])
Ser_1
# Out:
# 0     10
# 1     20
# 2     30
# 3    400
# 4    500
# dtype: int64

# %%
Paired={'Mouse':'Pad','Key':'Hole',
   'Wired':'Wireless','Numpy':'Pandas',
  'Series':'DataFrame','Laptop':'Computer',
  'Debt':'Equity','AI':'ML'}
Paired
# Out:
# {'Mouse': 'Pad',
#  'Key': 'Hole',
#  'Wired': 'Wireless',
#  'Numpy': 'Pandas',
#  'Series': 'DataFrame',
#  'Laptop': 'Computer',
#  'Debt': 'Equity',
#  'AI': 'ML'}

# %%
Paired.keys()
# Out:
# dict_keys(['Mouse', 'Key', 'Wired', 'Numpy', 'Series', 'Laptop', 'Debt', 'AI'])

# %%
par=pd.Series(Paired)
par
# Out:
# Mouse           Pad
# Key            Hole
# Wired      Wireless
# Numpy        Pandas
# Series    DataFrame
# Laptop     Computer
# Debt         Equity
# AI               ML
# dtype: object

# %%
par[-5:-1]
# Out:
# Numpy        Pandas
# Series    DataFrame
# Laptop     Computer
# Debt         Equity
# dtype: object

# %%
Series=df['Brand'][0:5]
Series
# Out:
# 0    Essentials
# 1        Adidas
# 2          Nike
# 3          Nike
# 4          Nike
# Name: Brand, dtype: object

# %% [markdown]
# # 2.Series Operation

# %%
type(df['Product Type'])
# Out:
# pandas.core.series.Series

# %%
df['Product Type']
# Out:
# 0       T-shirt
# 1      Sneakers
# 2      Sneakers
# 3        Hoodie
# 4      Sneakers
#          ...
# 348    Sneakers
# 349      Hoodie
# 350     Joggers
# 351    Sneakers
# 352    Sneakers
# Name: Product Type, Length: 353, dtype: object

# %%
df[df['Product Type']=='Sneakers'][0:2]
# Out:
#          Date     Product Name Product Type   Brand  Gender         Category  \
# 1  2022-08-22  Yeezy Boost 350     Sneakers  Adidas  Unisex       Streetwear
# 2  2022-04-03    Nike Dunk Low     Sneakers    Nike   Women  Limited Edition
#
#    Country  Quantity  Unit Price ($)  Amount ($)      Payment Mode
# 1      USA         2          267.34      534.68  Cash on Delivery
# 2  Germany         1          292.00      292.00  Cash on Delivery

# %%
df[df['Quantity']>2]['Quantity']
# Out:
# 0      5
# 3      4
# 8      3
# 9      4
# 12     3
#       ..
# 348    5
# 349    5
# 350    4
# 351    5
# 352    5
# Name: Quantity, Length: 225, dtype: int64

# %%
df['Unit Price ($)'][0:5]
# Out:
# 0    141.82
# 1    267.34
# 2    292.00
# 3    245.44
# 4    184.51
# Name: Unit Price ($), dtype: float64

# %%
df['Unit Price ($)'][0:4]*0.04
# Out:
# 0     5.6728
# 1    10.6936
# 2    11.6800
# 3     9.8176
# Name: Unit Price ($), dtype: float64

# %%
df['Amount ($)'][0:4]
# Out:
# 0    709.10
# 1    534.68
# 2    292.00
# 3    981.76
# Name: Amount ($), dtype: float64

# %%
df['Amount ($)'][0:4]/0.05
# Out:
# 0    14182.0
# 1    10693.6
# 2     5840.0
# 3    19635.2
# Name: Amount ($), dtype: float64

# %%
df.columns
# Out:
# Index(['Date', 'Product Name', 'Product Type', 'Brand', 'Gender', 'Category',
#        'Country', 'Quantity', 'Unit Price ($)', 'Amount ($)', 'Payment Mode'],
#       dtype='object')

# %%
df.Gender[0:4]
# Out:
# 0    Unisex
# 1    Unisex
# 2     Women
# 3       Men
# Name: Gender, dtype: object

# %%
myseries=df['Brand'].value_counts()
myseries
# Out:
# Brand
# Nike          107
# Adidas         70
# Off-White      48
# Puma           41
# Supreme        32
# New Era        29
# Essentials     26
# Name: count, dtype: int64

# %%
myseries.index
# Out:
# Index(['Nike', 'Adidas', 'Off-White', 'Puma', 'Supreme', 'New Era',
#        'Essentials'],
#       dtype='object', name='Brand')

# %%
myseries.values
# Out:
# array([107,  70,  48,  41,  32,  29,  26])

# %% [markdown]
# # 3.Pandas DataFrame

# %% [markdown]
# # DataFrame: A two-dimensional data structure with labeled axes (rows and columns). It is similar to a spreadsheet or an SQL table.

# %%
Data={'Name':pd.Series(['Aaron','Michael','Jack','Donald','Sam','Smith']),
     'Age':[29,40,80,24,12,52],
     'Height (cm)':[180,160,171,173,189,190],
     'Job':['Data Analyst','Accountant','Shopkeeper','IT Technician','HR Manager','Mayor'],
     'City':pd.Series(['Austin','Paris','New York','Dallas','Kerala','Kentucky'])}
Data
# Out:
# {'Name': 0      Aaron
#  1    Michael
#  2       Jack
#  3     Donald
#  4        Sam
#  5      Smith
#  dtype: object,
#  'Age': [29, 40, 80, 24, 12, 52],
#  'Height (cm)': [180, 160, 171, 173, 189, 190],
#  'Job': ['Data Analyst',
#   'Accountant',
#   'Shopkeeper',
#   'IT Technician',
#   'HR Manager',
#   'Mayor'],
#  'City': 0      Austin
#  1       Paris
#  2    New York
#  3      Dallas
#  4      Kerala
#  5    Kentucky
#  dtype: object}

# %%
Frame=pd.DataFrame(Data)
Frame
# Out:
#       Name  Age  Height (cm)            Job      City
# 0    Aaron   29          180   Data Analyst    Austin
# 1  Michael   40          160     Accountant     Paris
# 2     Jack   80          171     Shopkeeper  New York
# 3   Donald   24          173  IT Technician    Dallas
# 4      Sam   12          189     HR Manager    Kerala
# 5    Smith   52          190          Mayor  Kentucky

# %%
Frame[['Name','Job']]
# Out:
#       Name            Job
# 0    Aaron   Data Analyst
# 1  Michael     Accountant
# 2     Jack     Shopkeeper
# 3   Donald  IT Technician
# 4      Sam     HR Manager
# 5    Smith          Mayor

# %%
df[0:5]
# Out:
#          Date                Product Name Product Type       Brand  Gender  \
# 0  2022-05-27  Fear of God Essentials Tee      T-shirt  Essentials  Unisex
# 1  2022-08-22             Yeezy Boost 350     Sneakers      Adidas  Unisex
# 2  2022-04-03               Nike Dunk Low     Sneakers        Nike   Women
# 3  2022-07-13            Nike Tech Fleece       Hoodie        Nike     Men
# 4  2022-08-25               Jordan 1 High     Sneakers        Nike   Women
#
#           Category    Country  Quantity  Unit Price ($)  Amount ($)  \
# 0  Limited Edition      Japan         5          141.82      709.10
# 1       Streetwear        USA         2          267.34      534.68
# 2  Limited Edition    Germany         1          292.00      292.00
# 3  Limited Edition        USA         4          245.44      981.76
# 4           Casual  Australia         2          184.51      369.02
#
#        Payment Mode
# 0              Card
# 1  Cash on Delivery
# 2  Cash on Delivery
# 3  Cash on Delivery
# 4  Cash on Delivery

# %%
df[["Gender",'Country']][0:5]
# Out:
#    Gender    Country
# 0  Unisex      Japan
# 1  Unisex        USA
# 2   Women    Germany
# 3     Men        USA
# 4   Women  Australia

# %%
df[['Brand','Gender','Country']]
# Out:
#           Brand  Gender    Country
# 0    Essentials  Unisex      Japan
# 1        Adidas  Unisex        USA
# 2          Nike   Women    Germany
# 3          Nike     Men        USA
# 4          Nike   Women  Australia
# ..          ...     ...        ...
# 348        Nike     Men      India
# 349        Nike   Women    Germany
# 350        Puma   Women    Germany
# 351      Adidas     Men     Canada
# 352        Nike   Women      Japan
#
# [353 rows x 3 columns]

# %% [markdown]
# # 4.DataFrame Operation

# %%
Frame
# Out:
#       Name  Age  Height (cm)            Job      City
# 0    Aaron   29          180   Data Analyst    Austin
# 309  Limited Edition     USA         2          135.48      270.96
# 315  Limited Edition     USA         1          284.30      284.30
# 339           Casual     USA         3          110.20      330.60
# 347       Sportswear     USA         1          208.24      208.24
#
#          Payment Mode
# 1    Cash on Delivery
# 3    Cash on Delivery
# 8              Wallet
# 10   Cash on Delivery
# 14             Wallet
# 22             Wallet
# 30   Cash on Delivery
# 31   Cash on Delivery
# 49   Cash on Delivery
# 66   Cash on Delivery
# 70               Card
# 77               Card
# 79                UPI
# 85   Cash on Delivery
# 86               Card
# 87                UPI
# 94               Card
# 99   Cash on Delivery
# 113  Cash on Delivery
# 139               UPI
# 143  Cash on Delivery
# 144            Wallet
# 148  Cash on Delivery
# 157              Card
# 171            Wallet
# 174              Card
# 195              Card
# 199  Cash on Delivery
# 208            Wallet
# 221            Wallet
# 225              Card
# 238              Card
# 241               UPI
# 248              Card
# 250               UPI
# 257            Wallet
# 260               UPI
# 269            Wallet
# 288              Card
# 295            Wallet
# 304            Wallet
# 309  Cash on Delivery
# 315              Card
# 339              Card
# 347  Cash on Delivery

# %%
df[(df['Country']=='USA')&(df['Product Type']=='Sneakers')
# Out:
#            Date       Product Name Product Type   Brand  Gender  \
# 1    2022-08-22    Yeezy Boost 350     Sneakers  Adidas  Unisex
# 8    2022-06-20      Jordan 1 High     Sneakers    Nike   Women
# 10   2022-06-25    Yeezy Boost 350     Sneakers  Adidas     Men
# 14   2022-08-25  Adidas Ultraboost     Sneakers  Adidas  Unisex
# 31   2022-02-24      Nike Dunk Low     Sneakers    Nike   Women
# 49   2022-08-21      Nike Dunk Low     Sneakers    Nike   Women
# 79   2022-08-31    Yeezy Boost 350     Sneakers  Adidas     Men
# 86   2022-06-06      Jordan 1 High     Sneakers    Nike   Women
# 87   2022-08-29    Yeezy Boost 350     Sneakers  Adidas  Unisex
# 113  2022-01-24  Adidas Ultraboost     Sneakers  Adidas     Men
# 171  2022-06-26    Yeezy Boost 350     Sneakers  Adidas  Unisex
# 174  2022-01-03      Nike Dunk Low     Sneakers    Nike   Women
# 195  2022-01-17      Nike Dunk Low     Sneakers    Nike     Men
# 208  2022-02-26      Jordan 1 High     Sneakers    Nike     Men
# 225  2022-01-08  Adidas Ultraboost     Sneakers  Adidas   Women
# 248  2022-08-01      Jordan 1 High     Sneakers    Nike     Men
# 250  2022-01-04      Nike Dunk Low     Sneakers    Nike     Men
# 257  2022-01-01    Yeezy Boost 350     Sneakers  Adidas  Unisex
# 295  2022-02-27    Yeezy Boost 350     Sneakers  Adidas  Unisex
# 315  2022-05-26    Yeezy Boost 350     Sneakers  Adidas   Women
# 347  2022-03-10      Jordan 1 High     Sneakers    Nike   Women
#
#             Category Country  Quantity  Unit Price ($)  Amount ($)  \
# 1         Streetwear     USA         2          267.34      534.68
# 8         Streetwear     USA         3          199.47      598.41
# 10   Limited Edition     USA         1          117.18      117.18
# 14            Casual     USA         1          104.16      104.16
# 31        Sportswear     USA         2          203.05      406.10
# 49        Streetwear     USA         5          183.55      917.75
# 79   Limited Edition     USA         1           56.49       56.49
# 86   Limited Edition     USA         5          299.30     1496.50
# 87        Streetwear     USA         4          162.85      651.40
# 113  Limited Edition     USA         3          101.39      304.17
# 171           Casual     USA         3          209.69      629.07
# 174       Streetwear     USA         5          176.98      884.90
# 195  Limited Edition     USA         3          213.66      640.98
# 208  Limited Edition     USA         3           51.81      155.43
# 225       Sportswear     USA         5          275.27     1376.35
# 248       Streetwear     USA         4          130.97      523.88
# 250       Sportswear     USA         4          151.37      605.48
# 257           Casual     USA         1          202.42      202.42
# 295       Sportswear     USA         5          248.71     1243.55
# 315  Limited Edition     USA         1          284.30      284.30
# 347       Sportswear     USA         1          208.24      208.24
#
#          Payment Mode
# 1    Cash on Delivery
# 8              Wallet
# 10   Cash on Delivery
# 14             Wallet
# 31   Cash on Delivery
# 49   Cash on Delivery
# 79                UPI
# 86               Card
# 87                UPI
# 113  Cash on Delivery
# 171            Wallet
# 174              Card
# 195              Card
# 208            Wallet
# 225              Card
# 248              Card
# 250               UPI
# 257            Wallet
# 295            Wallet
# 315              Card
# 347  Cash on Delivery

# %%
df[(df['Country']=='USA') & 
    (df['Product Type']=='Sneakers')][['Country','Product Type']][0:5]
# Out:
#    Country Product Type
# 1      USA     Sneakers
# 8      USA     Sneakers
# 10     USA     Sneakers
# 14     USA     Sneakers
# 31     USA     Sneakers

# %%
df.describe()
# Out:
#          Quantity  Unit Price ($)   Amount ($)
# count  353.000000      353.000000   353.000000
# mean     3.107649      174.607054   547.034193
# std      1.408083       71.625710   343.084461
# min      1.000000       50.100000    50.100000
# 25%      2.000000      113.750000   268.780000
# 50%      3.000000      175.510000   494.400000
# 75%      4.000000      235.500000   783.930000
# max      5.000000      299.730000  1496.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            353 non-null    object
#  1   Product Name    353 non-null    object
#  2   Product Type    353 non-null    object
#  3   Brand           353 non-null    object
#  4   Gender          353 non-null    object
#  5   Category        353 non-null    object
#  6   Country         353 non-null    object
#  7   Quantity        353 non-null    int64
#  8   Unit Price ($)  353 non-null    float64
#  9   Amount ($)      353 non-null    float64
#  10  Payment Mode    353 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 30.5+ KB

# %%
Frame[0:3]
# Out:
#       Name  Age  Height (cm)           Job      City
# 0    Aaron   29          180  Data Analyst    Austin
# 1  Michael   40          160    Accountant     Paris
# 2     Jack   80          171    Shopkeeper  New York

# %%
Frame.drop(['Age','Height (cm)'],axis=1)[0:3]
# Out:
#       Name           Job      City
# 0    Aaron  Data Analyst    Austin
# 1  Michael    Accountant     Paris
# 2     Jack    Shopkeeper  New York

# %%
df[['Amount ($)','Unit Price ($)']].sum().to_frame()
# Out:
#                         0
# Amount ($)      193103.07
# Unit Price ($)   61636.29

# %%
Frame
# Out:
#       Name  Age  Height (cm)            Job      City
# 0    Aaron   29          180   Data Analyst    Austin
# 1  Michael   40          160     Accountant     Paris
# 2     Jack   80          171     Shopkeeper  New York
# 3   Donald   24          173  IT Technician    Dallas
# 4      Sam   12          189     HR Manager    Kerala
# 5    Smith   52          190          Mayor  Kentucky
